# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 622

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={api_key}&units={units}&city={city}&q="

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city).json()
try:
    lat.append(response['coord']['lat'])
    temp.append(response['main']['temp'])
    humid.append(response['main']['humidity'])
    cloud.append(response['clouds']['all'])
    wind.append(response['wind']['speed'])
except(KeyError):
    print("Missing field/result... skipping.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f93e49239f46> in <module>
#       8     response = requests.get(query_url + city).json()
#       9 try:
# ---> 10     lat.append(response['coord']['lat'])
#      11     temp.append(response['main']['temp'])
#      12     humid.append(response['main']['humidity'])
#
# NameError: name 'lat' is not defined

# %%
weather_lat = {
    "lat": lat
}
weather_data2=pd.DataFrame(weather_lat)
weather_data2.head()
# Out:
#      lat
# 0  37.16

# %%
weather_dict = {
    "city": cities,
    "lat": lat,
    "temp": temp,
    "humidity": humid,
    "cloudiness": cloud,
    "wind speed": wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-32804e3f7724> in <module>
#       7     "wind speed": wind
#       8 }
# ----> 9 weather_data = pd.DataFrame(weather_dict)
#      10 weather_data.head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7354     # figure out the index, if necessary
#    7355     if index is None:
# -> 7356         index = extract_index(arrays)
#    7357
#    7358     # don't force copy because getting jammed in an ndarray anyway
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    7400             lengths = list(set(raw_lengths))
#    7401             if len(lengths) > 1:
# -> 7402                 raise ValueError('arrays must all be same length')
#    7403
#    7404             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
for x in range(len(cities)):
    print(f"Processing Record {x}: | {cities[x]}")
# Out:
# Processing Record 0: | barentsburg
# Processing Record 1: | upernavik
# Processing Record 2: | rikitea
# Processing Record 3: | crateus
# Processing Record 4: | albany
# Processing Record 5: | portland
# Processing Record 6: | marrakesh
# Processing Record 7: | esperance
# Processing Record 8: | nsanje
# Processing Record 9: | ushuaia
# Processing Record 10: | san patricio
# Processing Record 11: | chuy
# Processing Record 12: | tucurui
# Processing Record 13: | attawapiskat
# Processing Record 14: | rundu
# Processing Record 15: | carnarvon
# Processing Record 16: | butaritari
# Processing Record 17: | buariki
# Processing Record 18: | tasiilaq
# Processing Record 19: | torbay
# Processing Record 20: | hermanus
# Processing Record 21: | ponta do sol
# Processing Record 22: | kihei
# Processing Record 23: | vaini
# Processing Record 24: | hobart
# Processing Record 25: | new norfolk
# Processing Record 26: | busselton
# Processing Record 27: | cape town
# Processing Record 28: | puerto ayora
# Processing Record 29: | svetlyy
# Processing Record 30: | visby
# Processing Record 31: | rio gallegos
# Processing Record 32: | ostrovnoy
# Processing Record 33: | krasnoselkup
# Processing Record 34: | hami
# Processing Record 35: | amderma
# Processing Record 36: | hamilton
# Processing Record 37: | castro
# Processing Record 38: | tiksi
# Processing Record 39: | bredasdorp
# Processing Record 40: | roald
# Processing Record 41: | el alto
# Processing Record 42: | pevek
# Processing Record 43: | sangar
# Processing Record 44: | hilo
# Processing Record 45: | pindiga
# Processing Record 46: | eldoret
# Processing Record 47: | raga
# Processing Record 48: | sao filipe
# Processing Record 49: | taolanaro
# Processing Record 50: | lebu
# Processing Record 51: | nanortalik
# Processing Record 52: | nemuro
# Processing Record 53: | talikota
# Processing Record 54: | belushya guba
# Processing Record 55: | bethel
# Processing Record 56: | kapaa
# Processing Record 57: | arraial do cabo
# Processing Record 58: | najran
# Processing Record 59: | rolla
# Processing Record 60: | namyslow
# Processing Record 61: | saskylakh
# Processing Record 62: | provideniya
# Processing Record 63: | necochea
# Processing Record 64: | qinggang
# Processing Record 65: | cidreira
# Processing Record 66: | mataura
# Processing Record 67: | vaitupu
# Processing Record 68: | rock sound
# Processing Record 69: | avarua
# Processing Record 70: | georgetown
# Processing Record 71: | rio tuba
# Processing Record 72: | karaul
# Processing Record 73: | sentyabrskiy
# Processing Record 74: | sofiysk
# Processing Record 75: | gerash
# Processing Record 76: | luganville
# Processing Record 77: | mahebourg
# Processing Record 78: | aklavik
# Processing Record 79: | illoqqortoormiut
# Processing Record 80: | san cristobal
# Processing Record 81: | bandarbeyla
# Processing Record 82: | ketchikan
# Processing Record 83: | little chute
# Processing Record 84: | fukue
# Processing Record 85: | zhigansk
# Processing Record 86: | saint george
# Processing Record 87: | samalaeulu
# Processing Record 88: | mar del plata
# Processing Record 89: | dutse
# Processing Record 90: | la paz
# Processing Record 91: | punta arenas
# Processing Record 92: | beyneu
# Processing Record 93: | kahului
# Processing Record 94: | ponta delgada
# Processing Record 95: | kalmunai
# Processing Record 96: | otradinskiy
# Processing Record 97: | kavieng
# Processing Record 98: | qaanaaq
# Processing Record 99: | slyudyanka
# Processing Record 100: | kungur
# Processing Record 101: | vao
# Processing Record 102: | thompson
# Processing Record 103: | pangnirtung
# Processing Record 104: | vryburg
# Processing Record 105: | yellowknife
# Processing Record 106: | atasu
# Processing Record 107: | rocha
# Processing Record 108: | barrow
# Processing Record 109: | lhokseumawe
# Processing Record 110: | shelburne
# Processing Record 111: | east london
# Processing Record 112: | boulder
# Processing Record 113: | port blair
# Processing Record 114: | oussouye
# Processing Record 115: | tessalit
# Processing Record 116: | naze
# Processing Record 117: | hengyang
# Processing Record 118: | bluff
# Processing Record 119: | nuuk
# Processing Record 120: | vila velha
# Processing Record 121: | sorvag
# Processing Record 122: | kenai
# Processing Record 123: | avanigadda
# Processing Record 124: | jamestown
# Processing Record 125: | antalaha
# Processing Record 126: | awjilah
# Processing Record 127: | presidencia roque saenz pena
# Processing Record 128: | mbuguni
# Processing Record 129: | saint-augustin
# Processing Record 130: | port alfred
# Processing Record 131: | jalu
# Processing Record 132: | kloulklubed
# Processing Record 133: | kidal
# Processing Record 134: | vestmannaeyjar
# Processing Record 135: | cherskiy
# Processing Record 136: | negombo
# Processing Record 137: | komsomolskiy
# Processing Record 138: | lompoc
# Processing Record 139: | quatre cocos
# Processing Record 140: | tsihombe
# Processing Record 141: | quartucciu
# Processing Record 142: | sao jose da coroa grande
# Processing Record 143: | mys shmidta
# Processing Record 144: | faanui
# Processing Record 145: | iqaluit
# Processing Record 146: | santa lucia
# Processing Record 147: | hithadhoo
# Processing Record 148: | cabo san lucas
# Processing Record 149: | sao miguel do araguaia
# Processing Record 150: | kushima
# Processing Record 151: | sirajganj
# Processing Record 152: | charlestown
# Processing Record 153: | tabiauea
# Processing Record 154: | kabanjahe
# Processing Record 155: | bandipur
# Processing Record 156: | srednekolymsk
# Processing Record 157: | shelton
# Processing Record 158: | north bend
# Processing Record 159: | cotonou
# Processing Record 160: | adwa
# Processing Record 161: | ribeira grande
# Processing Record 162: | mungeli
# Processing Record 163: | port elizabeth
# Processing Record 164: | khatanga
# Processing Record 165: | vila franca do campo
# Processing Record 166: | mogochin
# Processing Record 167: | lashio
# Processing Record 168: | airai
# Processing Record 169: | khuzhir
# Processing Record 170: | tuktoyaktuk
# Processing Record 171: | yerazgavors
# Processing Record 172: | mount gambier
# Processing Record 173: | los llanos de aridane
# Processing Record 174: | capinzal
# Processing Record 175: | isangel
# Processing Record 176: | olinda
# Processing Record 177: | vestmanna
# Processing Record 178: | bluefield
# Processing Record 179: | kemijarvi
# Processing Record 180: | panyutyne
# Processing Record 181: | boyolangu
# Processing Record 182: | grand river south east
# Processing Record 183: | atuona
# Processing Record 184: | gat
# Processing Record 185: | superior
# Processing Record 186: | souillac
# Processing Record 187: | teguise
# Processing Record 188: | maniitsoq
# Processing Record 189: | port lincoln
# Processing Record 190: | richards bay
# Processing Record 191: | kangaatsiaq
# Processing Record 192: | igrim
# Processing Record 193: | poronaysk
# Processing Record 194: | siilinjarvi
# Processing Record 195: | tuatapere
# Processing Record 196: | havre-saint-pierre
# Processing Record 197: | tommot
# Processing Record 198: | artyom
# Processing Record 199: | coihueco
# Processing Record 200: | port arthur
# Processing Record 201: | saldanha
# Processing Record 202: | huangnihe
# Processing Record 203: | freeport
# Processing Record 204: | port said
# Processing Record 205: | monchegorsk
# Processing Record 206: | aljezur
# Processing Record 207: | cedar city
# Processing Record 208: | turayf
# Processing Record 209: | andilamena
# Processing Record 210: | saint-philippe
# Processing Record 211: | mogwase
# Processing Record 212: | sitka
# Processing Record 213: | birjand
# Processing Record 214: | cockburn town
# Processing Record 215: | winslow
# Processing Record 216: | kendari
# Processing Record 217: | clyde river
# Processing Record 218: | champerico
# Processing Record 219: | limon
# Processing Record 220: | longonjo
# Processing Record 221: | maragogi
# Processing Record 222: | comodoro rivadavia
# Processing Record 223: | leningradskiy
# Processing Record 224: | chara
# Processing Record 225: | america dourada
# Processing Record 226: | fairbanks
# Processing Record 227: | trairi
# Processing Record 228: | vanimo
# Processing Record 229: | arkhangelskoye
# Processing Record 230: | adrar
# Processing Record 231: | nome
# Processing Record 232: | evensk
# Processing Record 233: | williams lake
# Processing Record 234: | broken hill
# Processing Record 235: | maridi
# Processing Record 236: | sisimiut
# Processing Record 237: | saleaula
# Processing Record 238: | grand gaube
# Processing Record 239: | prince george
# Processing Record 240: | salo
# Processing Record 241: | nguiu
# Processing Record 242: | cafarnaum
# Processing Record 243: | biak
# Processing Record 244: | port hueneme
# Processing Record 245: | hirara
# Processing Record 246: | hasaki
# Processing Record 247: | acapulco
# Processing Record 248: | la malbaie
# Processing Record 249: | coquimbo
# Processing Record 250: | bad munder
# Processing Record 251: | kaitangata
# Processing Record 252: | mirina
# Processing Record 253: | sibolga
# Processing Record 254: | chapais
# Processing Record 255: | kutum
# Processing Record 256: | ilulissat
# Processing Record 257: | tilichiki
# Processing Record 258: | muros
# Processing Record 259: | longyearbyen
# Processing Record 260: | caravelas
# Processing Record 261: | mega
# Processing Record 262: | galle
# Processing Record 263: | kodiak
# Processing Record 264: | valparaiso
# Processing Record 265: | karratha
# Processing Record 266: | pitsunda
# Processing Record 267: | nandurbar
# Processing Record 268: | tupik
# Processing Record 269: | bengkulu
# Processing Record 270: | panixtlahuaca
# Processing Record 271: | grants
# Processing Record 272: | nikolskoye
# Processing Record 273: | codrington
# Processing Record 274: | senador jose porfirio
# Processing Record 275: | luderitz
# Processing Record 276: | poya
# Processing Record 277: | berbera
# Processing Record 278: | po
# Processing Record 279: | lagoa
# Processing Record 280: | kuytun
# Processing Record 281: | yining
# Processing Record 282: | kununurra
# Processing Record 283: | poum
# Processing Record 284: | rawson
# Processing Record 285: | haines junction
# Processing Record 286: | yasnyy
# Processing Record 287: | samusu
# Processing Record 288: | gurskoye
# Processing Record 289: | turochak
# Processing Record 290: | sedelnikovo
# Processing Record 291: | susanino
# Processing Record 292: | rosarito
# Processing Record 293: | vite
# Processing Record 294: | pahrump
# Processing Record 295: | svetlogorsk
# Processing Record 296: | samarai
# Processing Record 297: | batticaloa
# Processing Record 298: | norman wells
# Processing Record 299: | lolua
# Processing Record 300: | aasiaat
# Processing Record 301: | talnakh
# Processing Record 302: | algiers
# Processing Record 303: | sao joao da barra
# Processing Record 304: | mahajanga
# Processing Record 305: | grindavik
# Processing Record 306: | padang
# Processing Record 307: | khalkhal
# Processing Record 308: | margate
# Processing Record 309: | luanda
# Processing Record 310: | hofn
# Processing Record 311: | mangochi
# Processing Record 312: | gondanglegi
# Processing Record 313: | kamenskoye
# Processing Record 314: | marcona
# Processing Record 315: | dikson
# Processing Record 316: | nabire
# Processing Record 317: | college
# Processing Record 318: | ayios matthaios
# Processing Record 319: | nouadhibou
# Processing Record 320: | omsukchan
# Processing Record 321: | halalo
# Processing Record 322: | kayes
# Processing Record 323: | buin
# Processing Record 324: | ancud
# Processing Record 325: | yulara
# Processing Record 326: | hovd
# Processing Record 327: | savasleyka
# Processing Record 328: | mayo
# Processing Record 329: | lata
# Processing Record 330: | pozo colorado
# Processing Record 331: | ashcroft
# Processing Record 332: | ilinskiy
# Processing Record 333: | mehamn
# Processing Record 334: | luza
# Processing Record 335: | mantua
# Processing Record 336: | miquelon
# Processing Record 337: | chokurdakh
# Processing Record 338: | warqla
# Processing Record 339: | aegviidu
# Processing Record 340: | fortuna
# Processing Record 341: | dingle
# Processing Record 342: | paamiut
# Processing Record 343: | rafsanjan
# Processing Record 344: | puerto penasco
# Processing Record 345: | okhotsk
# Processing Record 346: | palu
# Processing Record 347: | ijaki
# Processing Record 348: | san quintin
# Processing Record 349: | jieshi
# Processing Record 350: | sao gabriel da cachoeira
# Processing Record 351: | korla
# Processing Record 352: | meulaboh
# Processing Record 353: | artyk
# Processing Record 354: | alice springs
# Processing Record 355: | muriwai beach
# Processing Record 356: | bathsheba
# Processing Record 357: | mudanjiang
# Processing Record 358: | victoria
# Processing Record 359: | ketchenery
# Processing Record 360: | tevaitoa
# Processing Record 361: | sobolevo
# Processing Record 362: | lemon tree passage
# Processing Record 363: | liancheng
# Processing Record 364: | namatanai
# Processing Record 365: | bolungarvik
# Processing Record 366: | yarada
# Processing Record 367: | lorengau
# Processing Record 368: | emerald
# Processing Record 369: | imuris
# Processing Record 370: | geraldton
# Processing Record 371: | nizhneyansk
# Processing Record 372: | tamale
# Processing Record 373: | mata
# Processing Record 374: | belaya gora
# Processing Record 375: | cloquet
# Processing Record 376: | letlhakane
# Processing Record 377: | ledyard
# Processing Record 378: | buje
# Processing Record 379: | sabla
# Processing Record 380: | huacho
# Processing Record 381: | tanout
# Processing Record 382: | skibbereen
# Processing Record 383: | mehriz
# Processing Record 384: | tamboril
# Processing Record 385: | yalutorovsk
# Processing Record 386: | formoso do araguaia
# Processing Record 387: | cayenne
# Processing Record 388: | maneadero
# Processing Record 389: | avera
# Processing Record 390: | nichinan
# Processing Record 391: | arlit
# Processing Record 392: | parana
# Processing Record 393: | bambous virieux
# Processing Record 394: | lingao
# Processing Record 395: | hamada
# Processing Record 396: | yumen
# Processing Record 397: | rancho palos verdes
# Processing Record 398: | tanabe
# Processing Record 399: | xining
# Processing Record 400: | narsaq
# Processing Record 401: | praia da vitoria
# Processing Record 402: | berlevag
# Processing Record 403: | san carlos de bariloche
# Processing Record 404: | bobcaygeon
# Processing Record 405: | severo-kurilsk
# Processing Record 406: | maraa
# Processing Record 407: | mareeba
# Processing Record 408: | filingue
# Processing Record 409: | seymchan
# Processing Record 410: | methoni
# Processing Record 411: | faya
# Processing Record 412: | cap malheureux
# Processing Record 413: | pachino
# Processing Record 414: | toliary
# Processing Record 415: | lucapa
# Processing Record 416: | rungata
# Processing Record 417: | linda
# Processing Record 418: | alugan
# Processing Record 419: | kamenka
# Processing Record 420: | liverpool
# Processing Record 421: | diffa
# Processing Record 422: | esmeraldas
# Processing Record 423: | pershotravneve
# Processing Record 424: | kuopio
# Processing Record 425: | san jose
# Processing Record 426: | charyshskoye
# Processing Record 427: | phak hai
# Processing Record 428: | huejuquilla el alto
# Processing Record 429: | sens
# Processing Record 430: | shache
# Processing Record 431: | tateyama
# Processing Record 432: | beloha
# Processing Record 433: | leshukonskoye
# Processing Record 434: | tezu
# Processing Record 435: | chumikan
# Processing Record 436: | san lazaro
# Processing Record 437: | beringovskiy
# Processing Record 438: | maralal
# Processing Record 439: | aykhal
# Processing Record 440: | pisco
# Processing Record 441: | koson
# Processing Record 442: | kota belud
# Processing Record 443: | fagernes
# Processing Record 444: | yar-sale
# Processing Record 445: | iquique
# Processing Record 446: | sorland
# Processing Record 447: | sorong
# Processing Record 448: | popondetta
# Processing Record 449: | bireun
# Processing Record 450: | kathmandu
# Processing Record 451: | la ronge
# Processing Record 452: | tura
# Processing Record 453: | shellbrook
# Processing Record 454: | hihifo
# Processing Record 455: | kapuvar
# Processing Record 456: | rasipuram
# Processing Record 457: | luangwa
# Processing Record 458: | livingston
# Processing Record 459: | papara
# Processing Record 460: | inta
# Processing Record 461: | juigalpa
# Processing Record 462: | bisceglie
# Processing Record 463: | macaboboni
# Processing Record 464: | louisbourg
# Processing Record 465: | weihe
# Processing Record 466: | ulkan
# Processing Record 467: | port-cartier
# Processing Record 468: | dien bien
# Processing Record 469: | totma
# Processing Record 470: | tornio
# Processing Record 471: | jiazi
# Processing Record 472: | petauke
# Processing Record 473: | payakumbuh
# Processing Record 474: | kavaratti
# Processing Record 475: | prado
# Processing Record 476: | langarud
# Processing Record 477: | shieli
# Processing Record 478: | tiznit
# Processing Record 479: | kautokeino
# Processing Record 480: | red bluff
# Processing Record 481: | tignere
# Processing Record 482: | sertania
# Processing Record 483: | chagda
# Processing Record 484: | moree
# Processing Record 485: | ingham
# Processing Record 486: | hokitika
# Processing Record 487: | keti bandar
# Processing Record 488: | honiara
# Processing Record 489: | san antonio
# Processing Record 490: | wahran
# Processing Record 491: | port hardy
# Processing Record 492: | alyangula
# Processing Record 493: | talaya
# Processing Record 494: | dwarka
# Processing Record 495: | qaqortoq
# Processing Record 496: | tokzar
# Processing Record 497: | ahipara
# Processing Record 498: | mecca
# Processing Record 499: | warrnambool
# Processing Record 500: | huarmey
# Processing Record 501: | neyveli
# Processing Record 502: | klaksvik
# Processing Record 503: | karasjok
# Processing Record 504: | bargal
# Processing Record 505: | maarianhamina
# Processing Record 506: | saint anthony
# Processing Record 507: | lakes entrance
# Processing Record 508: | prnjavor
# Processing Record 509: | dongsheng
# Processing Record 510: | krasnoarmeysk
# Processing Record 511: | quesnel
# Processing Record 512: | moron
# Processing Record 513: | kem
# Processing Record 514: | vallenar
# Processing Record 515: | valle hermoso
# Processing Record 516: | shaunavon
# Processing Record 517: | pedernales
# Processing Record 518: | jinchang
# Processing Record 519: | camacha
# Processing Record 520: | te anau
# Processing Record 521: | cortes
# Processing Record 522: | vardo
# Processing Record 523: | buala
# Processing Record 524: | pundaguitan
# Processing Record 525: | baniyas
# Processing Record 526: | nadym
# Processing Record 527: | coxim
# Processing Record 528: | kismayo
# Processing Record 529: | ginir
# Processing Record 530: | amarante do maranhao
# Processing Record 531: | utiroa
# Processing Record 532: | waipawa
# Processing Record 533: | shingu
# Processing Record 534: | olafsvik
# Processing Record 535: | wodonga
# Processing Record 536: | tautira
# Processing Record 537: | chiredzi
# Processing Record 538: | gazli
# Processing Record 539: | ocos
# Processing Record 540: | malyn
# Processing Record 541: | hobyo
# Processing Record 542: | manggar
# Processing Record 543: | vilyuysk
# Processing Record 544: | revda
# Processing Record 545: | tiarei
# Processing Record 546: | talara
# Processing Record 547: | tres arroyos
# Processing Record 548: | taltal
# Processing Record 549: | kushmurun
# Processing Record 550: | lasa
# Processing Record 551: | havoysund
# Processing Record 552: | ngaoundere
# Processing Record 553: | birao
# Processing Record 554: | touros
# Processing Record 555: | mailsi
# Processing Record 556: | polewali
# Processing Record 557: | coronado
# Processing Record 558: | beihai
# Processing Record 559: | pochutla
# Processing Record 560: | premia de mar
# Processing Record 561: | aflu
# Processing Record 562: | urengoy
# Processing Record 563: | guerrero negro
# Processing Record 564: | big bend
# Processing Record 565: | catemaco
# Processing Record 566: | tuzha
# Processing Record 567: | ternate
# Processing Record 568: | katsuura
# Processing Record 569: | sena madureira
# Processing Record 570: | manzanillo
# Processing Record 571: | maple creek
# Processing Record 572: | cedral
# Processing Record 573: | mesaria
# Processing Record 574: | uwayl
# Processing Record 575: | santa cruz de la palma
# Processing Record 576: | quthing
# Processing Record 577: | urdzhar
# Processing Record 578: | honningsvag
# Processing Record 579: | marawi
# Processing Record 580: | tual
# Processing Record 581: | seddon
# Processing Record 582: | alem paraiba
# Processing Record 583: | manado
# Processing Record 584: | tari
# Processing Record 585: | lavrentiya
# Processing Record 586: | ilheus
# Processing Record 587: | vangaindrano
# Processing Record 588: | yekaterinoslavka
# Processing Record 589: | egvekinot
# Processing Record 590: | adamas
